# %%
import mysql.connector as sql
import pymongo
import pandas as pd

# %%
mydb = sql.connect(host='localhost',user='root',passwd='YES',use_pure=True)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-4-0ab0e9f5709d> in <module>
# ----> 1 mydb = sql.connect(host='localhost',user='root',passwd='YES',use_pure=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\__init__.py in connect(*args, **kwargs)
#     269     if HAVE_CEXT and not use_pure:
#     270         return CMySQLConnection(*args, **kwargs)
# --> 271     return MySQLConnection(*args, **kwargs)
#     272 Connect = connect  # pylint: disable=C0103
#     273
#
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\connection.py in __init__(self, *args, **kwargs)
#     105         if kwargs:
#     106             try:
# --> 107                 self.connect(**kwargs)
#     108             except:
#     109                 # Tidy-up underlying socket on failure
#
# ...

# %%
cursor = mydb.cursor()

# %%
cursor.execute("show databases")
cursor.fetchall()
# Out:
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('student',),
#  ('student12',),
#  ('sys',),
#  ('world',)]

# %%
mydb = sql.connect(host='localhost',user='root',passwd='8878692774@sarang',use_pure=True,database='performance_schema')
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-3-6d86c49c4308> in <module>
# ----> 1 mydb = sql.connect(host='localhost',user='root',passwd='8878692774@sarang',use_pure=True,database='performance_schema')
#
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\__init__.py in connect(*args, **kwargs)
#     269     if HAVE_CEXT and not use_pure:
#     270         return CMySQLConnection(*args, **kwargs)
# --> 271     return MySQLConnection(*args, **kwargs)
#     272 Connect = connect  # pylint: disable=C0103
#     273
#
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\connection.py in __init__(self, *args, **kwargs)
#     105         if kwargs:
#     106             try:
# --> 107                 self.connect(**kwargs)
#     108             except:
#     109                 # Tidy-up underlying socket on failure
#
# ...

# %%
cursor = mydb.cursor()

# %%
cursor.execute("show tables")
cursor.fetchall()
# Out:
# [('accounts',),
#  ('binary_log_transaction_compression_stats',),
#  ('cond_instances',),
#  ('data_lock_waits',),
#  ('data_locks',),
#  ('events_errors_summary_by_account_by_error',),
#  ('events_errors_summary_by_host_by_error',),
#  ('events_errors_summary_by_thread_by_error',),
#  ('events_errors_summary_by_user_by_error',),
#  ('events_errors_summary_global_by_error',),
#  ('events_stages_current',),
#  ('events_stages_history',),
#  ('events_stages_history_long',),
#  ('events_stages_summary_by_account_by_event_name',),
#  ('events_stages_summary_by_host_by_event_name',),
#  ('events_stages_summary_by_thread_by_event_name',),
#  ('events_stages_summary_by_user_by_event_name',),
#  ('events_stages_summary_global_by_event_name',),
#  ('events_statements_current',),
#  ('events_statements_histogram_by_digest',),
#  ('events_statements_histogram_global',),
#  ('events_statements_history',),
#  ('events_statements_history_long',),
# ...

# %%
cursor.execute('select * from user_defined_functions')
pd.DataFrame(cursor.fetchall())
# Out:
#                                   0        1         2 3  4
# 0     innodb_redo_log_archive_start  integer  function    1
# 1  mysqlx_get_prepared_statement_id  integer  function    1
# 2      innodb_redo_log_archive_stop  integer  function    1
# 3       mysqlx_generate_document_id     char  function    1
# 4     innodb_redo_log_archive_flush  integer  function    1
# 5                      mysqlx_error     char  function    1

# %%
import pymongo

# %%
DEFAULT_CONNECTION_URL = "mongodb://localhost:27017/"
DB_NAME = "iNeuron"

# Establish a connection with mongoDB
client = pymongo.MongoClient(DEFAULT_CONNECTION_URL)

# Create a DB
dataBase = client[DB_NAME]

# %%
client.list_database_names()
# Out:
# ['admin', 'config', 'crawlerDB', 'demoDB', 'local', 'profession', 'yojna']

# %%
COLLECTION_NAME = "iNeuron_Products"
collection = dataBase[COLLECTION_NAME]

# %%
record = {'companyName': 'iNeuron',
         'product': 'Affordable AI',
         'courseOffered': 'Deep Learning for Computer Vision'}

collection.insert_one(record)

# %%
list_of_records = [
    {'companyName': 'iNeuron',
     'product': 'Affordable AI',
     'courseOffered': 'Machine Learning with Deployment'},
    
    {'companyName': 'iNeuron',
     'product': 'Affordable AI',
     'courseOffered': 'Deep Learning for NLP and Computer vision'},
    
    {'companyName': 'iNeuron',
     'product': 'Master Program',
     'courseOffered': 'Data Science Masters Program'}
]

rec = collection.insert_many(list_of_records)

# %%
pd.DataFrame(collection.find())
# Out:
#                         _id companyName         product  \
# 0  5f8d89e0df1360c67a7fc66e     iNeuron   Affordable AI
# 1  5f8d89f4df1360c67a7fc66f     iNeuron   Affordable AI
# 2  5f8d89f4df1360c67a7fc670     iNeuron   Affordable AI
# 3  5f8d89f4df1360c67a7fc671     iNeuron  Master Program
#
#                                courseOffered
# 0          Deep Learning for Computer Vision
# 1           Machine Learning with Deployment
# 2  Deep Learning for NLP and Computer vision
# 3               Data Science Masters Program

# %%
import pymongo

# %%
client = pymongo.MongoClient("mongodb://localhost:27017/")

# %%
client.list_database_names()
# Out:
# ['admin',
#  'config',
#  'crawlerDB',
#  'demoDB',
#  'iNeuron',
#  'local',
#  'profession',
#  'yojna']

# %%
mydb = client["crawlerDB"]

# %%
mydb.collection_names()
# Out:
# <ipython-input-116-fbf09febc8fb>:1: DeprecationWarning: collection_names is deprecated. Use list_collection_names instead.
#   mydb.collection_names()
# ['mi', 'minotebook', 'rahul', 'jeans', 'car', 'samsung', 'sara', 'camera']

# %%
coll1 = mydb["minotebook"]

# %%
pd.DataFrame(coll1.find())
# Out:
#                          _id     Product               Name     Rating  \
# 0   5f6b26c887320b170f1bcd4f  minotebook           Sam  Adi          5
# 1   5f6b26c887320b170f1bcd50  minotebook   Sharmistha banik          5
# 2   5f6b26c887320b170f1bcd51  minotebook  Flipkart Customer          5
# 3   5f6b26c887320b170f1bcd52  minotebook  Flipkart Customer          4
# 4   5f6b26c887320b170f1bcd53  minotebook  Flipkart Customer          5
# 5   5f6b26c887320b170f1bcd54  minotebook  Flipkart Customer          5
# 6   5f6b26c887320b170f1bcd55  minotebook       saheb sarkar          5
# 7   5f6b26c887320b170f1bcd56  minotebook      Nikki Roberts          5
# 8   5f6b26c887320b170f1bcd57  minotebook       Pamila Begum          5
# 9   5f6b26c887320b170f1bcd58  minotebook  Flipkart Customer          5
# 10  5f6b26c887320b170f1bcd59  minotebook            No Name  No Rating
#
#             CommentHead                                            Comment
# ...

# %%
quary = {"$and":[{"Product":"minotebook"},{"Rating":{"$lte":"4"}}]}

pd.DataFrame(coll1.find(quary))
# Out:
#                         _id     Product               Name Rating CommentHead  \
# 0  5f6b26c887320b170f1bcd52  minotebook  Flipkart Customer      4   Wonderful
#
#                                              Comment
# 0  it's good.. came exactly what I saw.. I'm lovi...

# %%
client = pymongo.MongoClient("mongodb://localhost:27017/")

# %%
client.list_database_names()
# Out:
# ['admin',
#  'config',
#  'crawlerDB',
#  'demoDB',
#  'iNeuron',
#  'local',
#  'profession',
#  'yojna']

# %%
mydb = client["demoDB"]

# %%
mydb.list_collection_names()
# Out:
# ['mongo_demo']

# %%
col1 = mydb["mongo_demo"]

# %%
pd.DataFrame(col1.find({}))
# Out:
#                          _id Serial No GRE Score TOEFL Score  \
# 0   5f55def04e4130e5b2fc95ff      9996       336         118
# 1   5f55def04e4130e5b2fc9601      9994       334         119
# 2   5f55df8cd15d64089763d523      9996       336         118
# 3   5f55df8cd15d64089763d525      9994       334         119
# 4   5f55df8cd15d64089763d526      9993       337         118
# 5   5f6a02da5ceee4e3b2c1247f      9998       337         118
# 6   5f6a02da5ceee4e3b2c12480      9997       337         118
# 7   5f6a02da5ceee4e3b2c12481      9996       336         118
# 8   5f6a02da5ceee4e3b2c12482      9995       337         118
# 9   5f6a02da5ceee4e3b2c12483      9994       334         119
# 10  5f6a02da5ceee4e3b2c12484      9993       337         118
# 11  5f6a368d675ea6841d3706b4      9998       337         118
# 12  5f6a368d675ea6841d3706b5      9997       337         118
# 13  5f6a368d675ea6841d3706b6      9996       336         118
# ...

# %%
client = pymongo.MongoClient("mongodb+srv://root:8878692774sarang@cluster0.yha3e.mongodb.net/sample_airbnb?retryWrites=true&w=majority")
db = client.test

# %%
client.list_database_names()
# Out:
# ['sample_airbnb',
#  'sample_analytics',
#  'sample_geospatial',
#  'sample_mflix',
#  'sample_restaurants',
#  'sample_supplies',
#  'sample_training',
#  'sample_weatherdata',
#  'admin',
#  'local']

# %%
mydb1 = client["sample_airbnb"]

# %%
col1 = mydb1["listingsAndReviews"]

# %%
df = pd.DataFrame(col1.find({}))

# %%
client.close()

# %%
df.shape
# Out:
# (5555, 42)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 42 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   _id                    5555 non-null   object
#  1   listing_url            5555 non-null   object
#  2   name                   5555 non-null   object
#  3   summary                5555 non-null   object
#  4   space                  5555 non-null   object
#  5   description            5555 non-null   object
#  6   neighborhood_overview  5555 non-null   object
#  7   notes                  5555 non-null   object
#  8   transit                5555 non-null   object
#  9   access                 5555 non-null   object
#  10  interaction            5555 non-null   object
#  11  house_rules            5555 non-null   object
#  12  property_type          5555 non-null   object
#  13  room_type              5555 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# _id                         0
# listing_url                 0
# name                        0
# summary                     0
# space                       0
# description                 0
# neighborhood_overview       0
# notes                       0
# transit                     0
# access                      0
# interaction                 0
# house_rules                 0
# property_type               0
# room_type                   0
# bed_type                    0
# minimum_nights              0
# maximum_nights              0
# cancellation_policy         0
# last_scraped                0
# calendar_last_scraped       0
# first_review             1388
# last_review              1388
# accommodates                0
# bedrooms                    5
# beds                       13
# number_of_reviews           0
# bathrooms                  10
# amenities                   0
# price                       0
# security_deposit         2084
# cleaning_fee             1531
# ...

# %%
client = pymongo.MongoClient("mongodb+srv://root:8878692774sarang@cluster0.yha3e.mongodb.net/test")

# %%
client.list_database_names()
# Out:
# ['sample_airbnb',
#  'sample_analytics',
#  'sample_geospatial',
#  'sample_mflix',
#  'sample_restaurants',
#  'sample_supplies',
#  'sample_training',
#  'sample_weatherdata',
#  'admin',
#  'local']

# %%
mydb = client["sample_weatherdata"]

# %%
mydb.list_collection_names()
# Out:
# ['data']

# %%
col1 = mydb["data"]

# %%
for i in col1.find({}):
    print(i)
# Out:
# {'_id': ObjectId('5553a998e4b02cf7151190b8'), 'st': 'x+47600-047900', 'ts': datetime.datetime(1984, 3, 5, 13, 0), 'position': {'type': 'Point', 'coordinates': [-47.9, 47.6]}, 'elevation': 9999, 'callLetters': 'VCSZ', 'qualityControlProcess': 'V020', 'dataSource': '4', 'type': 'FM-13', 'airTemperature': {'value': -3.1, 'quality': '1'}, 'dewPoint': {'value': 999.9, 'quality': '9'}, 'pressure': {'value': 1015.3, 'quality': '1'}, 'wind': {'direction': {'angle': 999, 'quality': '9'}, 'type': '9', 'speed': {'rate': 999.9, 'quality': '9'}}, 'visibility': {'distance': {'value': 999999, 'quality': '9'}, 'variability': {'value': 'N', 'quality': '9'}}, 'skyCondition': {'ceilingHeight': {'value': 99999, 'quality': '9', 'determination': '9'}, 'cavok': 'N'}, 'sections': ['AG1'], 'precipitationEstimatedObservation': {'discrepancy': '2', 'estimatedWaterDepth': 999}}
# ...

# %%
df = pd.DataFrame(col1.find({}))

# %%
df.shape
# Out:
# (10000, 27)
