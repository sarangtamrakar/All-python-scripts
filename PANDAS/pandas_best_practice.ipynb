# %%
import pandas as pd
import numpy as np

# %%
url='https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
df=pd.read_table(url)
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.tail(1)
# Out:
#       order_id  quantity           item_name  \
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
print(df.shape[0]) #row
df.shape[1] #column
# Out:
# 4622
# 5

# %%
#Which was the most ordered item in once?

# %%
df.head(1)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
#
#   item_price
# 0     $2.39

# %%
seti=df[['item_name','quantity']]
seti=seti.sort_values(by=['quantity'],ascending=False)
seti.head(1)
# Out:
#                          item_name  quantity
# 3598  Chips and Fresh Tomato Salsa        15

# %%
#Which was the most total ordered item?

# %%
df.groupby(['item_name']).sum()['quantity'].sort_values(ascending=False).head(1)
# both can be done
# Out:
# item_name
# Chicken Bowl    761
# Name: quantity, dtype: int64

# %%
seti=df[['item_name','quantity']]
seti.groupby('item_name').sum().sort_values(by='quantity',ascending=False).head(1)
# Out:
#               quantity
# item_name
# Chicken Bowl       761

# %%
#Which was the mean total ordered item

# %%
seti=df[['item_name','quantity']]
seti.groupby('item_name').mean().sort_values(by='quantity',ascending=False).head(1)
# Out:
#            quantity
# item_name
# Bowl            2.0

# %%
#What was the most ordered item in the choice_description column?

# %%
s=df[['choice_description','quantity']]
s=s.groupby('choice_description').sum()
s=s.sort_values(by=['quantity'],ascending=False).head(1)
s
# Out:
#                     quantity
# choice_description
# [Diet Coke]              159

# %%
#Turn the item price into a float
df.head(1)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
#
#   item_price
# 0     $2.39

# %%
def fl(x):
    return float(x[1:-1])



df['item_price']=df['item_price'].apply(fl)

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
#How much was the revenue for the period in the dataset?

# %%
df.head(1)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
#
#    item_price
# 0        2.39

# %%
revenue=(df['item_price']*df['quantity']).sum()
revenue
# Out:
# 39237.02

# %%
#print a data frame with only two columns item_name and item_price
seti3=df[['item_name','item_price']]
seti3
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl       16.98
# ...                                     ...         ...
# 4617                          Steak Burrito       11.75
# 4618                          Steak Burrito       11.75
# 4619                     Chicken Salad Bowl       11.25
# 4620                     Chicken Salad Bowl        8.75
# 4621                     Chicken Salad Bowl        8.75
#
# [4622 rows x 2 columns]

# %%
# delete the duplicates in item_name and quantity
dupli = df.drop_duplicates(['item_name','quantity'],keep='last')
dupli
# Out:
#       order_id  quantity            item_name  \
# 445        193         3                 Bowl
# 506        212         2        Carnitas Bowl
# 521        217         1         Crispy Tacos
# 613        253         2     Steak Salad Bowl
# 673        279         1                 Bowl
# ...        ...       ...                  ...
# 4614      1831         1        Bottled Water
# 4615      1832         1   Chicken Soft Tacos
# 4616      1832         1  Chips and Guacamole
# 4618      1833         1        Steak Burrito
# 4621      1834         1   Chicken Salad Bowl
#
#                                      choice_description  item_price
# 445   [Braised Carnitas, Pinto Beans, [Sour Cream, C...       22.20
# 506   [Roasted Chili Corn Salsa, [Fajita Vegetables,...       23.50
# 521               [Adobo-Marinated and Grilled Chicken]        7.40
# 613   [Tomatillo Red Chili Salsa, [Fajita Vegetables...       23.78
# ...

# %%
# select only the products with quantity equals to 1
filt=df[df['quantity']==1]
filt
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 5            3         1                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
# sort the values from the most to less expensive & give the name of item with  most expensive
se3=df.sort_values(by=['item_price'],ascending=False)
se3.head(1)[['item_price','item_name']]
# Out:
#       item_price                     item_name
# 3598       44.25  Chips and Fresh Tomato Salsa

# %%
aa= df[['item_price','item_name']]
aa.groupby('item_name').sum()
aa.sort_values(by='item_price',ascending=False).head(1)
# Out:
#       item_price                     item_name
# 3598       44.25  Chips and Fresh Tomato Salsa

# %%
#What was the quantity of the most expensive item ordered?
bb=df[['item_name','item_price','quantity']]
bb.groupby('item_name').sum()
bb.sort_values(by='item_price',ascending=False).head(1)
# Out:
#                          item_name  item_price  quantity
# 3598  Chips and Fresh Tomato Salsa       44.25        15

# %%
#How many times were a Veggie Salad Bowl ordered?

# %%
cc=df[['item_name','quantity']]
cc.groupby('item_name').sum().loc['Veggie Salad Bowl']
# Out:
# quantity    18
# Name: Veggie Salad Bowl, dtype: int64

# %%
df[df['item_name']=='Veggie Salad Bowl'].sum().to_frame()
# Out:
#                                                                     0
# order_id                                                        17303
# quantity                                                           18
# item_name           Veggie Salad BowlVeggie Salad BowlVeggie Salad...
# choice_description  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...
# item_price          $11.25 $11.25 $11.25 $11.25 $8.75 $8.75 $11.25...

# %%
url='https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv'
df2=pd.read_csv(url)
df2.head()
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
# 3  1963   188483000  4109500   316970   3792500    8640          17650
# 4  1964   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %%
df2.shape
# Out:
# (55, 12)

# %%
df2.dtypes
# Out:
# Year                  int64
# Population            int64
# Total                 int64
# Violent               int64
# Property              int64
# Murder                int64
# Forcible_Rape         int64
# Robbery               int64
# Aggravated_assault    int64
# Burglary              int64
# Larceny_Theft         int64
# Vehicle_Theft         int64
# dtype: object

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                55 non-null     int64
#  1   Population          55 non-null     int64
#  2   Total               55 non-null     int64
#  3   Violent             55 non-null     int64
#  4   Property            55 non-null     int64
#  5   Murder              55 non-null     int64
#  6   Forcible_Rape       55 non-null     int64
#  7   Robbery             55 non-null     int64
#  8   Aggravated_assault  55 non-null     int64
#  9   Burglary            55 non-null     int64
#  10  Larceny_Theft       55 non-null     int64
#  11  Vehicle_Theft       55 non-null     int64
# dtypes: int64(12)
# memory usage: 5.3 KB

# %%
#Convert the type of the column Year to datetime64

# %%
df2['Year']=pd.to_datetime(df2['Year'],format='%Y')
df2.dtypes
# Out:
# Year                  datetime64[ns]
# Population                     int64
# Total                          int64
# Violent                        int64
# Property                       int64
# Murder                         int64
# Forcible_Rape                  int64
# Robbery                        int64
# Aggravated_assault             int64
# Burglary                       int64
# Larceny_Theft                  int64
# Vehicle_Theft                  int64
# dtype: object

# %%
#Set the Year column as the index of the dataframe

# %%
df2.set_index(['Year'],inplace=True)

# %%
df2.sort_values(by='Year',inplace=True)

# %%
df2.head(1)
# Out:
#             Population    Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   179323175  3384200   288460   3095700    9110          17190
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01   107840              154320    912100        1855400
#
#             Vehicle_Theft
# Year
# 1960-01-01         328200

# %%
#Select just the 'Murder' and 'Robbery' columns from the DataFrame

# %%
# df2[['Murder','Robbery']]
df2.loc[:,['Murder','Robbery']]
# Out:
#             Murder  Robbery
# Year
# 1960-01-01    9110   107840
# 1961-01-01    8740   106670
# 1962-01-01    8530   110860
# 1963-01-01    8640   116470
# 1964-01-01    9360   130390
# 1965-01-01    9960   138690
# 1966-01-01   11040   157990
# 1967-01-01   12240   202910
# 1968-01-01   13800   262840
# 1969-01-01   14760   298850
# 1970-01-01   16000   349860
# 1971-01-01   17780   387700
# 1972-01-01   18670   376290
# 1973-01-01   19640   384220
# 1974-01-01   20710   442400
# 1975-01-01   20510   470500
# 1976-01-01   18780   427810
# 1977-01-01   19120   412610
# 1978-01-01   19560   426930
# 1979-01-01   21460   480700
# 1980-01-01   23040   565840
# 1981-01-01   22520   592910
# 1982-01-01   21010   553130
# 1983-01-01   19310   506570
# 1984-01-01   18690   485010
# 1985-01-01   18980   497870
# 1986-01-01   20613   542775
# 1987-01-01   20096   517704
# 1988-01-01   20680   542970
# 1989-01-01   21500   578330
# 1990-01-01   23440   639270
# 1991-01-01   24700   687730
# ...

# %%
#Select the data in rows [3, 4, 8] and in columns ['Murder', 'Robbery']

# %%
df2.loc[df2.index[[3,4,8]],['Murder','Robbery']]
# Out:
#             Murder  Robbery
# Year
# 1963-01-01    8640   116470
# 1964-01-01    9360   130390
# 1968-01-01   13800   262840

# %%
df2.iloc[[3,4,8],[5,7]]
# Out:
#             Forcible_Rape  Aggravated_assault
# Year
# 1963-01-01          17650              174210
# 1964-01-01          21420              203050
# 1968-01-01          31670              286700

# %%
#Select only the rows where the number of murder is greater than 24,000

# %%
df2.head(1)
# Out:
#             Population    Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   179323175  3384200   288460   3095700    9110          17190
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01   107840              154320    912100        1855400
#
#             Vehicle_Theft
# Year
# 1960-01-01         328200

# %%
df2[df2.Murder>24000]
# Out:
#             Population     Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1991-01-01   252177000  14872900  1911770  12961100   24700         106590
# 1993-01-01   257908000  14144800  1926020  12218800   24530         106010
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1991-01-01   687730             1092740   3157200        8142200
# 1993-01-01   659870             1135610   2834800        7820900
#
#             Vehicle_Theft
# Year
# 1991-01-01        1661700
# 1993-01-01        1563100

# %%
#Select the rows the murder is between 20k and 24k (inclusive)

# %%
df2[df2.Murder.between(20000,24000)]
# Out:
#             Population     Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1974-01-01   211392000  10253400   974720   9278700   20710          55400
# 1975-01-01   213124000  11292400  1039710  10252700   20510          56090
# 1979-01-01   220099000  12249500  1208030  11041500   21460          76390
# 1980-01-01   225349264  13408300  1344520  12063700   23040          82990
# 1981-01-01   229146000  13423800  1361820  12061900   22520          82500
# 1982-01-01   231534000  12974400  1322390  11652000   21010          78770
# 1986-01-01   240132887  13211869  1489169  11722700   20613          91459
# 1987-01-01   242282918  13508700  1483999  12024700   20096          91110
# 1988-01-01   245807000  13923100  1566220  12356900   20680          92490
# 1989-01-01   248239000  14251400  1646040  12605400   21500          94500
# 1990-01-01   248709873  14475600  1820130  12655500   23440         102560
# ...

# %%
#Calculate the mean murder for each different year in df, show in which year most year happened

# %%
ww=df2[['Year','Murder']]
ww.groupby('Year').mean()
ww.sort_values(by='Murder',ascending=False)
ww.head(1)
# Out:
#         Year  Murder
# 0 1960-01-01    9110

# %%
#Sort df first by the values in the 'Murder' in decending order,
#then by the value in the 'Violent' column in ascending order.

# %%
df2.head(1)
# Out:
#         Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0 1960-01-01   179323175  3384200   288460   3095700    9110          17190
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200

# %%
df2.sort_values(by=['Murder','Violent'],ascending=[False,True])
# Out:
#          Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 31 1991-01-01   252177000  14872900  1911770  12961100   24700         106590
# 33 1993-01-01   257908000  14144800  1926020  12218800   24530         106010
# 32 1992-01-01   255082000  14438200  1932270  12505900   23760         109060
# 30 1990-01-01   248709873  14475600  1820130  12655500   23440         102560
# 34 1994-01-01   260341000  13989500  1857670  12131900   23330         102220
# 20 1980-01-01   225349264  13408300  1344520  12063700   23040          82990
# 21 1981-01-01   229146000  13423800  1361820  12061900   22520          82500
# 35 1995-01-01   262755000  13862700  1798790  12063900   21610          97470
# 29 1989-01-01   248239000  14251400  1646040  12605400   21500          94500
# 19 1979-01-01   220099000  12249500  1208030  11041500   21460          76390
# 22 1982-01-01   231534000  12974400  1322390  11652000   21010          78770
# ...

# %%
import pandas as pd

# %%
url='https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv'
df3=pd.read_csv(url)
df3
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
#Which continent drinks more beer on average?

# %%
aa=df3[['continent','beer_servings']]
aa.groupby('continent').mean().sort_values(by='beer_servings',ascending=False).head(1)
# Out:
#            beer_servings
# continent
# EU            193.777778

# %%
# which continent had drink most in one time  (not average)..imp topic

# %%
aa=df3[['continent','beer_servings']]
aa.sort_values(by='beer_servings',ascending=False).head(1)
# Out:
#     continent  beer_servings
# 117        AF            376

# %%
#Which continent drinks most beer total ?

# %%
aa=df3[['continent','beer_servings']]
aa.groupby('continent').sum().sort_values(by='beer_servings',ascending=False).head(1)
# Out:
#            beer_servings
# continent
# EU                  8720

# %%
#For each continent print the statistics for wine consumption.

# %%
df3.head(1)
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS

# %%
qq=df3[['continent','wine_servings']]
qq.groupby('continent').describe().transpose()
# Out:
# continent                    AF          AS          EU         OC          SA
# wine_servings count   53.000000   44.000000   45.000000   16.00000   12.000000
#               mean    16.264151    9.068182  142.222222   35.62500   62.416667
#               std     38.846419   21.667034   97.421738   64.55579   88.620189
#               min      0.000000    0.000000    0.000000    0.00000    1.000000
#               25%      1.000000    0.000000   59.000000    1.00000    3.000000
#               50%      2.000000    1.000000  128.000000    8.50000   12.000000
#               75%     13.000000    8.000000  195.000000   23.25000   98.500000
#               max    233.000000  123.000000  370.000000  212.00000  221.000000
