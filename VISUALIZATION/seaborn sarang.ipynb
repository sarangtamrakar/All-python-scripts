# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
df=pd.read_csv(r'C:\Users\saran\Downloads\datasets_727551_1263738_heart_failure_clinical_records_dataset.csv')
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
df['anaemia'] = pd.Categorical(df['anaemia'].astype('object'))
df['diabetes'] = pd.Categorical(df['diabetes'].astype('object'))
df['high_blood_pressure'] = pd.Categorical(df['high_blood_pressure'].astype('object'))
df['sex'] = pd.Categorical(df['sex'].astype('object')).rename_categories(['MALE','FEMALE'])
df['smoking'] = pd.Categorical(df['smoking'].astype('object'))
df['DEATH_EVENT'] = pd.Categorical(df['DEATH_EVENT'].astype('object'))

# %%
df.dtypes
# Out:
# age                          float64
# anaemia                     category
# creatinine_phosphokinase       int64
# diabetes                    category
# ejection_fraction              int64
# high_blood_pressure         category
# platelets                    float64
# serum_creatinine             float64
# serum_sodium                   int64
# sex                         category
# smoking                     category
# time                           int64
# DEATH_EVENT                 category
# dtype: object

# %%
sns.catplot('DEATH_EVENT','age',data=df,kind='box',palette='rainbow')

# %%
sns.catplot('DEATH_EVENT','age',data=df,kind='bar',palette='rainbow')

# %%
sns.catplot('DEATH_EVENT','creatinine_phosphokinase',data=df,kind='box')

# %%
sns.catplot('DEATH_EVENT','creatinine_phosphokinase',data=df,kind='bar')

# %%
sns.catplot('DEATH_EVENT','ejection_fraction',data=df,kind='box',palette='rainbow')

# %%
sns.catplot('DEATH_EVENT','ejection_fraction',data=df,kind='bar',palette='rainbow')

# %%
sns.catplot('DEATH_EVENT','platelets',data=df,kind='box',palette='spring')

# %%
sns.catplot('DEATH_EVENT','platelets',data=df,kind='bar')

# %%
sns.catplot('DEATH_EVENT','serum_creatinine',data=df,kind='box')

# %%
sns.catplot('DEATH_EVENT','serum_creatinine',data=df,kind='bar')

# %%
sns.catplot('DEATH_EVENT','serum_sodium',data=df,kind='box')

# %%
sns.catplot('DEATH_EVENT','serum_sodium',data=df,kind='bar')

# %%
sns.catplot('DEATH_EVENT','time',data=df,kind='box')

# %%
sns.catplot('DEATH_EVENT','time',data=df,kind='bar')

# %%
sns.relplot('age','creatinine_phosphokinase',data=df,hue='DEATH_EVENT')

# %%
sns.relplot('age','creatinine_phosphokinase',data=df,hue='DEATH_EVENT')

# %%
df.dtypes.to_frame()
# Out:
#                                  0
# age                        float64
# anaemia                   category
# creatinine_phosphokinase     int64
# diabetes                  category
# ejection_fraction            int64
# high_blood_pressure       category
# platelets                  float64
# serum_creatinine           float64
# serum_sodium                 int64
# sex                       category
# smoking                   category
# time                         int64
# DEATH_EVENT               category

# %%
sns.lmplot('age','time',data=df,hue='DEATH_EVENT')
